# %% [markdown]
# <a href="https://colab.research.google.com/github/Akhorramrouz/My-body-Your-choice/blob/main/choose_project_for_nlp_course.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd "/content/drive/MyDrive/Ninisite_data/"
# Out:
# /content/drive/.shortcut-targets-by-id/17n9ThmBuSNYzMl6Lc6y8Z59PR5LPK_1r/Ninisite_data

# %%
df = pd.read_csv("topics_comments.csv")

# %%
df_filtered = df[df['text'].str.contains("کرونا")]

# %%
topics = pd.read_csv("topic_titles_cleanedStemmed.csv")

# %%
topics.head()
# Out:
#    Unnamed: 0        id                                         title  \
# 0    10004455  10004455          قدیر تو سریال خواهر برادران میمیره؟؟
# 1    10027217  10027217               رتبه قبولی حسابداری کنکور ریاضی
# 2    10073795  10073795  به نظرتون۸تومن بدم اموزش ارزدیجیتال می ارزه؟
# 3    10082532  10082532                               حقوق شرکت فولاد
# 4    10110293  10110293        پیکاپ لاین هایی که بلدین 😁😎❤️‍🔥 مخ زنی
#
#                                                 text        date  \
# 0                           \nتصادف کرد میمیره؟؟🥺🥺\n  1401/10/10
# 1  \nسلام دوستان میخواستم بدونم رتبه قبولی حسابدا...  1401/10/13
# 2  \nمیخام ارزدیجیتال اموزش ببینمو کارکنم گفتن ام...  1401/10/19
# 3  \nسلام دوستان کسی رو میشناسید تو شرکت فولاد کا...  1401/10/20
# 4  \nبچه ها هر کی پیکاپ لاین باحالی بلده بگه : پی...  1401/10/23
#
#                                             username  \
# 0                                              qlabi
# ...

# %%
topics_filtered = topics[topics['text'].str.contains("سقط")]  # & topics['text'].str.contains("گناه")

# %%
pd.set_option('display.max_colwidth', 30)

# %%
2500*.003
# Out:
# 7.5

# %%
topics_filtered.head()
# Out:
#       Unnamed: 0       id                          title  \
# 2633     8019410  8019410                سقط جنین ۴هفته
# 2655     8035541  8035541                   تست دی ان ای
# 3671     9032419  9032419  اونایی که میگن بدبختیم پول...
# 4507     1495276  1495276                     خیانت همسر
# 4628     3259569  3259569          کیا افتادگی رحم دارن
#
#                                text        date  \
# 2633  \nخواهرم حامله است بچه اش ...  1400/11/04
# 2655  \nپسرمه ۱۰ سالشه وعاشق بود...  1400/11/07
# 3671  \nذهنت محدوده👌🏻👌🏻باور داشت...  1401/04/26
# 4507  \nدوستا یه نظر میخواستم بپ...  1396/09/02
# 4628  \nمن یه سقط ۶ ماهه داشتم ب...  1398/06/28
#
#                            username                         userid  \
# 2633  %d8%b4%d8%a7%d9%87-%d8%af%...  5e44938e-74cb-4f9f-8ff7-b3...
# 2655  %d8%a8%d9%87%d8%a7%db%b1%d...  98aa8196-1403-4bad-97a1-9d...
# 3671  %da%af%d9%84-%d9%85%d9%86%...  34dd1b98-4821-410b-bb3a-6e...
# ...

# %%
print(len(topics_filtered))
for t in topics_filtered.loc[topics_filtered.forum_title == "legal_consultancy"].sample(20)['text']:
    print(t)
    print("="*20)
# Out:
# 2455
#
# سلام.الان باردار هستم . دکتر برام استرحت پزشکی نوشته ، 2بار قبلا سقط داشتم و الان هم لکه بینی دارم.حالا میخوام ببینم اگه من از مرخصی پزشکی استفاده کنم بعد از زایمان هم میتونم از مرخصی زایمان که 6 ماه هست هم استفاده کنم یا دیگه نمیشه؟؟؟؟؟  چون بعدش باز میخوام برم سرکاردر طول استراحت پزشکی بهم حقوق میدن؟؟؟هیچی از این قانونها سر در نمیارم . اگه میشه راهنمایی کنید.ممنون.
#
# ...
#
# سلام خانوم گلای قشنگم😍من تاالان بخاطر سقط های قبلم استراحت کامل بودم ونمیتونستم جایی جزدکتر برم ولی ازاین به بعد میخوام ازدوران بارداریم لذت کافی رو ببرم که بعدا پشیمون نشم ولی فعلانمیدونم باید چیکارکنم میشه شماها کمکم کنین؟؟؟😊
#
# ...
#
# سرزنش نكنيد خودم خيلي حالم بدهامروز سقط جنين داشتم نميدونم چرا با اينكه خيلي خوابم مياد ولي نميتونم بخوابمكيا مثل من بودن؟ كي من خوب ميشم؟
#
# ...
#
# من یه سقط ۶ ماهه داشتم بعد عکس رنگی گرفتم فهمیدم افتادگی رحم دارم چند سال بعد از اون باردار شدم و دهانه رحممو دوختم ک بچه نیوفته مثل همون ۶ ماهه شه.دوختم و بچم الان سالمه خداروشکر.
#
# ...
#
# ...

# %%
dff = df.merge(topics_filtered, on='topic_id').drop_duplicates(subset='id_x')

# %%
dff.loc[dff['text_x'].str.contains("حق")]
# Out:
#        Unnamed: 0_x         id_x                         text_x      date_x  \
# 130              41  245010492.0  قبل گرونیا چرا اونم جای عا...  1401/04/26
# 138              45  245010606.0  خب قطعا حق مردم ما این نیس...  1401/04/26
# 152              52  245010761.0  پول هست کاملادرسته،اماعادل...  1401/04/26
# 182              67  245011153.0  من خودم به شعرت ایمان دارم...  1401/04/26
# 218              85  245011664.0  عزیزم حرفت چه درست باشه چه...  1401/04/26
# ...             ...          ...                            ...         ...
# 86534            65  228112799.0  من ۲۰ سالمه سه تا بچه ایم ...  1400/12/07
# 86608             2  195664686.0  والا گلم گناه داره اون بچه...  1400/03/30
# 86709            36  209938172.0  واااای چ وحشتناک .. اولش ک...  1400/07/08
# 86780            48  211314613.0  خداروشکر کن خدا بهت نعمت د...  1400/07/19
# 86903            35  274053243.0  ممنون گلم نمیدونم چی بگم و...  1401/11/23
#
# ...
